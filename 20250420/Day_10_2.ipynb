# %%
# !nvidia-smi
# Out:
# Mon Apr 21 12:53:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Step 1: Write CUDA code to a file
code = r'''
#include <stdio.h>
#include <stdlib.h>
#include <algorithm>
#include <time.h>

#define BLOCK_SIZE 256
#define BLOCK_DIM 8
#define IN_TILE_DIM BLOCK_DIM
#define OUT_TILE_DIM (IN_TILE_DIM - 2)

// Error checking macro
#define CHECK_CUDA_ERROR(call) { \
    cudaError_t err = call; \
    if (err != cudaSuccess) { \
        fprintf(stderr, "CUDA error in %s at line %d: %s\n", \
                __FILE__, __LINE__, cudaGetErrorString(err)); \
        exit(EXIT_FAILURE); \
    } \
}

__global__ void stencil_kernel(float* in, float* out, unsigned int n)
{
  unsigned int i = blockIdx.z * OUT_TILE_DIM + threadIdx.z -1;
  unsigned int j = blockIdx.y * OUT_TILE_DIM + threadIdx.y -1;
  unsigned int k = blockIdx.x * OUT_TILE_DIM + threadIdx.x -1;
  float C0 = 0.5f;
  float C1 = 0.25f;

  __shared__ float in_s[IN_TILE_DIM][IN_TILE_DIM][IN_TILE_DIM];
  if (i >= 0 && j >=0 && j < n && k >=0 && k < n)
  {
    in_s[blockIdx.z][blockIdx.y][blockIdx.x] = in[i*n*n + j*n +k];
  }
  __syncthreads();
  if (i >= 1 && i < n-1 && j >= 1 && j < n - 1 && k >= 1 && k < n -1)
  {
    if (threadIdx.x >= 1 && threadIdx.x < blockDim.x -1 && threadIdx.y >= 1 && threadIdx.y < blockDim.y -1 && threadIdx.z >= 1 && threadIdx.z < blockDim.z -1)
    {
      out[i*n*n + j*n + k] = C0*in_s[threadIdx.x][threadIdx.y][threadIdx.z] +
                            C1*(in[threadIdx.x][threadIdx.y][threadIdx.z - 1] +
                                in[threadIdx.x][threadIdx.y][threadIdx.z + 1] +
                                in[threadIdx.x][threadIdx.y - 1][threadIdx.z] +
                                in[threadIdx.x][threadIdx.y + 1][threadIdx.z] +
                                in[threadIdx.x - 1][threadIdx.y][threadIdx.z] +
                                in[threadIdx.x + 1][threadIdx.y][threadIdx.z]);
    }
  }
}




void stencil_gpu(float* in, float* out, unsigned int n)
{
  float *in_d, *out_d;
  size_t size = n*n*n*sizeof(float);

  // Allocate device memory
  CHECK_CUDA_ERROR(cudaMalloc((void**) &in_d, size));
  CHECK_CUDA_ERROR(cudaMalloc((void**) &out_d, size));

  cudaDeviceSynchronize();

  CHECK_CUDA_ERROR(cudaMemcpy(in_d, in, size, cudaMemcpyHostToDevice));
  cudaDeviceSynchronize();

  dim3 numThreadsPerBlock(BLOCK_DIM,BLOCK_DIM,BLOCK_DIM);
  dim3 numBlocks((n + OUT_TILE_DIM - 1)/ OUT_TILE_DIM,
                 (n + OUT_TILE_DIM - 1)/ OUT_TILE_DIM,
                 (n + OUT_TILE_DIM - 1)/ OUT_TILE_DIM);
  stencil_kernel<<< numBlocks, numThreadsPerBlock>>>(in_d,out_d,n);
  // Check for kernel launch errors
  CHECK_CUDA_ERROR(cudaGetLastError());

  // Wait for kernel to finish
  CHECK_CUDA_ERROR(cudaDeviceSynchronize());

  cudaMemcpy(out,out_d, n*n*n*sizeof(float), cudaMemcpyDeviceToHost);

  cudaFree(in_d);
  cudaFree(out_d);

}
int main()
{
  const unsigned int n = 5;

  float* input = (float*)malloc(n*n*n*sizeof(float));
  float* output = (float*)malloc(n*n*n*sizeof(float));

  srand(42);
  for (unsigned int i = 0; i<n*n*n; i++) {
    input[i] = float(rand())/RAND_MAX;
  }


  stencil_gpu(input,output,n);
  for (unsigned int i = 0; i<1500; i++) {
      printf("%f",output[i]);
  }

  return 0;
}

'''

# Step 2: Save to file
with open('vec_add.cu', 'w') as f:
    f.write(code)

# Step 3: Compile using nvcc
# Ref: https://stackoverflow.com/questions/73361454/i-am-getting-zeros-as-a-result-of-vector-additon-in-cuda-and-no-errors
# !nvcc -arch=sm_75 vec_add.cu -o vec_add

# Step 4: Run the binary
# !./vec_add
# Out:
# 0.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000001.1867841.5431821.5390590.0000000.0000000.9090681.3587691.3430370.0000000.0000000.9922820.8961750.9508780.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.9098191.1887191.2978150.0000000.0000001.1072141.2153571.1597020.0000000.0000001.1631460.8053410.7817090.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000001.2150720.8880370.8582670.0000000.0000001.2518991.0316911.0300660.0000000.0000001.3965850.9069270.7756220.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000004822177514157213323960797626368.0000001076471704663581786112.00000013401006462375683141828345856.00000017258319504289841394221056.00000017845639624245156773888000.00000018106454337665250623488.00000075260926043837962997744009216.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.000000-nan-nan0.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.000000-nan-nan0.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000004176560607329825849344.0000000.0000000.0000000.0000000.0000000.0000004822177514157213323960797626368.0000001076471704663581786112.00000013401006462375683141828345856.00000017258319504289841394221056.00000017831767672701727191072768.00000018106454337665250623488.00000075260926043837962997744009216.0000000.0000000.0000000.0000000.000 ...

# %%
 # !nvprof ./vec_add --profile-from-start off
# Out:
# ==16659== NVPROF is profiling process 16659, command: ./vec_add --profile-from-start off
# 0.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.0000000.000000 ...
# ==16659== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   44.43%  95.103us         1  95.103us  95.103us  95.103us  [CUDA memcpy DtoH]
#                    42.07%  90.047us         1  90.047us  90.047us  90.047us  [CUDA memcpy HtoD]
#                    13.50%  28.896us         1  28.896us  28.896us  28.896us  stencil_kernel(float*, float*, unsigned int)
#       API calls:   98.15%  86.068ms         2  43.034ms  3.8320us  86.064ms  cudaMalloc
#                     1.24%  1.0875ms         2  543.77us  245.87us  841.68us  cudaMemcpy
#                     0.17%  144.83us         1  144.83us  144.83us  144.83us  cudaLaunchKernel
#                     0.15%  128.64us         3  42.880us  5.2620us  92.989us  cudaDeviceSynchronize
#                     0.14%  124.06us       114  1.0880us     101ns  51.022us  cuDeviceGetAttribute
#                     0.13%  114.61us         2  57.305us  10.224us  104.39us  cudaFree
#                     0.01%  10.468us         1  10.468us  10.468us  10.468us  cuDeviceGetName
#                     0.01%  5.9200us         1  5.9200us  5.9200us  5.9200us  cuDeviceGetPCIBusId
#                     0.00%  1.3340us         3     444ns     122ns  1.0340us  cuDeviceGetCount
#                     0.00%     816ns         2     408ns     127ns     689ns  cuDeviceGet
#                     0.00%     731ns         1     731ns     731ns     731ns  cudaGetLastError
#                     0.00%     381ns         1     381ns     381ns     381ns  cuModuleGetLoadingMode
#                     0.00%     351ns         1     351ns     351ns     351ns  cuDeviceTotalMem
#                     0.00%     202ns         1     202ns     202ns     202ns  cuDeviceGetUuid
